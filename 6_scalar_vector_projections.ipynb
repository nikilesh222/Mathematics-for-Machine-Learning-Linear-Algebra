# %%
relative_path = "./assets/videos/6.mp4"
from common_def import show_image, play_video, show_full_path

play_video(relative_path)
# Out:
# Absolute path: c:\Users\sAI\Desktop\AI_ML_Roadmap\LinearAlgebra\Notes\assets\videos\6.mp4

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image_path = './assets/images/scalar_and_vector_projection.png'

show_image(image_path, 150)
