# %%
from common_def import show_image, play_video, show_full_path

play_video("./assets/videos/7.mp4")
# Out:
# Absolute path: c:\Users\sAI\Desktop\AI_ML_Roadmap\LinearAlgebra\Notes\assets\videos\7.mp4

# %%
image_path = './assets/images/vector_by_basis_e.png'
show_image(image_path, 125)

image_path = './assets/images/7_1.png'
show_image(image_path, 250)

image_path = './assets/images/7_2.png'
show_image(image_path, 250)

image_path = './assets/images/7_3.png'
show_image(image_path, 250)

image_path = './assets/images/7_4.png'
show_image(image_path, 250)

image_path = './assets/images/7_5.png'
show_image(image_path, 250)

image_path = './assets/images/7_6.png'
show_image(image_path, 250)

image_path = './assets/images/7_7.png'
show_image(image_path, 250)

# %%
pdf_path = './assets/test_questions/ChangingbasisCoursera.pdf'

show_full_path(pdf_path)
# Out:
# Absolute path: c:\Users\sAI\Desktop\AI_ML_Roadmap\LinearAlgebra\Notes\assets\test_questions\ChangingbasisCoursera.pdf
