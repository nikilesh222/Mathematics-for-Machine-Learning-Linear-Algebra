# %%
from common_def import show_image, play_video, show_full_path

import numpy as np
import matplotlib.pyplot as plt

play_video("./assets/videos/14.mp4")
# Out:
# Absolute path: c:\Users\sAI\Desktop\AI_ML_Roadmap\LinearAlgebra\Notes\assets\videos\14.mp4

# %%
img_path = "./assets/images/14_1.png"
show_image(img_path, 200)

img_path = "./assets/images/14_2.png"
show_image(img_path, 200)

img_path = "./assets/images/14_3.png"
show_image(img_path, 200)

img_path = "./assets/images/14_4.png"
show_image(img_path, 200)

img_path = "./assets/images/14_5.png"
show_image(img_path, 200)

img_path = "./assets/images/14_6.png"
show_image(img_path, 200)
