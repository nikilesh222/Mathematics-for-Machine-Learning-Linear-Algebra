# %%
from common_def import show_image, play_video, show_full_path

play_video("./assets/videos/11.mp4")
# Out:
# Absolute path: c:\Users\sAI\Desktop\AI_ML_Roadmap\LinearAlgebra\Notes\assets\videos\11.mp4

# %%
img_path = "./assets/images/11_1.png"
show_image(img_path, 150)

img_path = "./assets/images/11_2.png"
show_image(img_path, 200)

img_path = "./assets/images/11_3.png"
show_image(img_path, 200)

img_path = "./assets/images/11_4.png"
show_image(img_path, 200)

img_path = "./assets/images/11_5.png"
show_image(img_path, 200)

img_path = "./assets/images/11_6.png"
show_image(img_path, 200)

img_path = "./assets/images/11_7.png"
show_image(img_path, 200)
